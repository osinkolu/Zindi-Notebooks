# %%
# !pip install -qq datasets>=2.6.1
# !pip install -qq git+https://github.com/huggingface/transformers
# !pip install -qq librosa
# !pip install -qq evaluate>=0.30
# !pip install -qq jiwer
# !pip install -qq gradio
# !pip install -qq accelerate -U

# %%
name = "openai/whisper-base"

# %%
#!python -c "from huggingface_hub.hf_api import HfFolder; HfFolder.save_token('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')"

# %%
from transformers import WhisperTokenizer
tokenizer = WhisperTokenizer.from_pretrained(name, language="Swahili", task="transcribe")
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/840 [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/2.20M [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/494k [00:00<?, ?B/s]
# Downloading (…)main/normalizer.json:   0%|          | 0.00/52.7k [00:00<?, ?B/s]
# Downloading (…)in/added_tokens.json:   0%|          | 0.00/2.08k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/2.08k [00:00<?, ?B/s]

# %%
import pandas as pd
import os

# %%
train = pd.read_csv("/kaggle/input/swahili-audio-dataset/train.csv")#.head(20)
test = pd.read_csv("/kaggle/input/swahili-audio-dataset/test.csv")#.head(20)
train["path"] = "/kaggle/input/swahili-audio-dataset/all_wav/content/all_wav_files/" + train["audio_ID"] +".wav"
test["path"] = "/kaggle/input/swahili-audio-dataset/all_wav/content/all_wav_files/" + test["audio_ID"] + ".wav"
test["sentence"] = " "
train
# Out:
#              audio_ID                                               path  \
# 0      audio_faa7312a  /kaggle/input/swahili-audio-dataset/all_wav/co...
# 1      audio_643a10c1  /kaggle/input/swahili-audio-dataset/all_wav/co...
# 2      audio_5b626e74  /kaggle/input/swahili-audio-dataset/all_wav/co...
# 3      audio_5972c5f3  /kaggle/input/swahili-audio-dataset/all_wav/co...
# 4      audio_deebd5b0  /kaggle/input/swahili-audio-dataset/all_wav/co...
# ...               ...                                                ...
# 19088  audio_020c9902  /kaggle/input/swahili-audio-dataset/all_wav/co...
# 19089  audio_7de63630  /kaggle/input/swahili-audio-dataset/all_wav/co...
# 19090  audio_a52c777e  /kaggle/input/swahili-audio-dataset/all_wav/co...
# 19091  audio_9adccc74  /kaggle/input/swahili-audio-dataset/all_wav/co...
# 19092  audio_127be360  /kaggle/input/swahili-audio-dataset/all_wav/co...
#
#                                                 sentence
# 0                         huko kwa Wakiroba Mkoa wa Mara
# 1      Alingaa katika medani za kisiasa na uongozi nd...
# 2                   Vitu saba ambavyo kila baba atakuwa.
# 3      inaonyesha mawaziri wapya ambao wamechukua naf...
# 4                    ee hii pia inatumiwa na kiwanda cha
# ...                                                  ...
# 19088                   bado timu zitapata nafasi katika
# 19089  Wabunge wapo huru kufanya mikutano ya hadhara ...
# 19090  aah mimi sio mkaaji sana mzee hata mazungumzo ...
# 19091  rini na saba hadi kumalizika kwake mwaka wa el...
# 19092    kila nchi ya asili Katika siasa ya nje Marekani
#
# [19093 rows x 3 columns]

# %%
test
# Out:
#             audio_ID                                               path  \
# 0     audio_3c2f423a  /kaggle/input/swahili-audio-dataset/all_wav/co...
# 1     audio_ca8009ec  /kaggle/input/swahili-audio-dataset/all_wav/co...
# 2     audio_fffcdb86  /kaggle/input/swahili-audio-dataset/all_wav/co...
# 3     audio_0e3e8e6f  /kaggle/input/swahili-audio-dataset/all_wav/co...
# 4     audio_859b792d  /kaggle/input/swahili-audio-dataset/all_wav/co...
# ...              ...                                                ...
# 3162  audio_bdc72517  /kaggle/input/swahili-audio-dataset/all_wav/co...
# 3163  audio_50ee5991  /kaggle/input/swahili-audio-dataset/all_wav/co...
# 3164  audio_b9867662  /kaggle/input/swahili-audio-dataset/all_wav/co...
# 3165  audio_a0739877  /kaggle/input/swahili-audio-dataset/all_wav/co...
# 3166  audio_ae65cf8a  /kaggle/input/swahili-audio-dataset/all_wav/co...
#
#      sentence
# 0
# 1
# 2
# 3
# 4
# ...       ...
# 3162
# 3163
# 3164
# 3165
# 3166
#
# [3167 rows x 3 columns]

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# Load the CSV file into a pandas DataFrame
df = train.copy()

# Split the DataFrame into train and validation sets
train, valid = train_test_split(df, test_size=0.2, random_state=42)

# Save the train and validation DataFrames to CSV files
train.to_csv('train_split.csv', index=False)
valid.to_csv('valid_split.csv', index=False)
test.to_csv("test.csv", index=False)

print("Splitting complete. Train and validation CSV files created.")
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Splitting complete. Train and validation CSV files created.

# %%
def load_data(data_files):
  "Load data using hugginface dataset.load_dataset()"
  data = load_dataset("csv", data_files=data_files)
  return data

chars_to_remove_regex = '[\,\?\.\!\-\;\:\"\“\%\‘\”\']'

def remove_special_characters(batch, column_name = "sentence"):
    batch[column_name] = re.sub(chars_to_remove_regex, '', batch[column_name])
    return batch

def replace_extra_characters(batch,column_name="sentence"):
    batch[column_name] = re.sub('[ç]', 'c', batch[column_name])
    batch[column_name] = re.sub('[é]', 'e', batch[column_name])
    batch[column_name] = re.sub('[...]', '', batch[column_name])
    batch[column_name] = re.sub('[\t]', '', batch[column_name])
    return batch

def extract_all_chars(batch,column_name="sentence"):
  all_text = " ".join(batch[column_name])
  vocab = list(set(all_text))
  return {"vocab": [vocab], "all_text": [all_text]}


def speech_file_to_array_fn(batch,column_name = "sentence", audio_folder = "/kaggle/input/swahili-audio-dataset/all_wav/content/all_wav_files/"):
    speech_array, sampling_rate = librosa.load(audio_folder + batch["audio_ID"]+".wav", mono=True, sr=16000)
    batch["speech"] = np.array(speech_array, dtype = np.float32)
    batch["sampling_rate"] = sampling_rate
    batch["target_text"] = batch[column_name]
    return batch

def prepare_dataset(batch):
    # load and resample audio data from 48 to 16kHz
    audio = batch["speech"]

    # compute log-Mel input features from input audio array
    batch["input_features"] = processor(np.array(batch["speech"]), sampling_rate=16000).input_features[0]

    # encode target text to label ids
    batch["labels"] = tokenizer(batch["target_text"]).input_ids
    return batch

# %%
from transformers import WhisperProcessor
processor = WhisperProcessor.from_pretrained(name, language="Swahili", task="transcribe")
# Out:
# Downloading (…)rocessor_config.json:   0%|          | 0.00/185k [00:00<?, ?B/s]

# %%
import torch

from dataclasses import dataclass
from typing import Any, Dict, List, Union
from transformers import WhisperProcessor

@dataclass
class DataCollatorSpeechSeq2SeqWithPadding:
    processor: WhisperProcessor
    padding: Union[bool, str] = True

    def __call__(self, features: List[Dict[str, Union[List[int], torch.Tensor]]]) -> Dict[str, torch.Tensor]:
        # split inputs and labels since they have to be of different lengths and need different padding methods
        # first treat the audio inputs by simply returning torch tensors
        input_features = [{"input_features": feature["input_features"]} for feature in features]
        batch = self.processor.feature_extractor.pad(input_features, return_tensors="pt")

        # get the tokenized label sequences
        label_features = [{"input_ids": feature["labels"]} for feature in features]
        # pad the labels to max length
        labels_batch = self.processor.tokenizer.pad(label_features, return_tensors="pt")

        # replace padding with -100 to ignore loss correctly
        labels = labels_batch["input_ids"].masked_fill(labels_batch.attention_mask.ne(1), -100)

        # if bos token is appended in previous tokenization step,
        # cut bos token here as it's append later anyways
        if (labels[:, 0] == self.processor.tokenizer.bos_token_id).all().cpu().item():
            labels = labels[:, 1:]

        batch["labels"] = labels

        return batch

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np
import random
from datasets import load_dataset, load_metric, Audio
import re
import json

import torch
import librosa
import IPython.display as ipd

from dataclasses import dataclass, field
from typing import Any, Dict, List, Optional, Union

# %%
wer_metric = load_metric("wer")
def compute_metrics(pred):
    pred_logits = pred.predictions
    pred_ids = np.argmax(pred_logits, axis=-1)

    pred.label_ids[pred.label_ids == -100] = processor.tokenizer.pad_token_id

    pred_str = processor.batch_decode(pred_ids)
    # we do not want to group tokens when computing the metric
    label_str = processor.batch_decode(pred.label_ids, group_tokens=False)

    wer = wer_metric.compute(predictions=pred_str, references=label_str)

    return {"wer": wer}
# Out:
# Downloading builder script:   0%|          | 0.00/1.90k [00:00<?, ?B/s]

# %%
from transformers import WhisperForConditionalGeneration
model = WhisperForConditionalGeneration.from_pretrained(name)
# Out:
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.98k [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/290M [00:00<?, ?B/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/3.78k [00:00<?, ?B/s]

# %%
model.config.forced_decoder_ids = None
model.config.suppress_tokens = []

# %%
# ### STEP 1
data_files = {
   "train": "train_split.csv",
             "valid": "valid_split.csv",
             "test": "test.csv"
             }
# # load data
data = load_data(data_files)

# # clean data
data["train"] = data["train"].map(remove_special_characters)
data["valid"] = data["valid"].map(remove_special_characters)
data["test"] = data["test"].map(remove_special_characters)

data["train"] = data["train"].map(replace_extra_characters)
data["valid"] = data["valid"].map(replace_extra_characters)
data["test"] = data["test"].map(replace_extra_characters)


# !mkdir "artifacts/"



data["train"] = data["train"].map(speech_file_to_array_fn,
                                remove_columns=data["train"].column_names)
data["valid"] = data["valid"].map(speech_file_to_array_fn,
                                remove_columns=data["valid"].column_names)
data["test"] = data["test"].map(speech_file_to_array_fn,
                               remove_columns=data["test"].column_names)

print("check data")
rand_int = random.randint(0, len(data)-1)

#print(data["train"][rand_int]["speech"])
#print("Input array shape:", np.array(data["train"][rand_int]["speech"]).shape)
#print("Sampling rate:", data["train"][rand_int]["sampling_rate"])
ipd.Audio(data=data["train"][rand_int]["speech"], autoplay=True, rate=16000)
# Out:
# Downloading and preparing dataset csv/default to /root/.cache/huggingface/datasets/csv/default-3b70cbff2e3d6826/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519...
# Downloading data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Dataset csv downloaded and prepared to /root/.cache/huggingface/datasets/csv/default-3b70cbff2e3d6826/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519. Subsequent calls will reuse this data.
# /opt/conda/lib/python3.10/site-packages/datasets/packaged_modules/csv/csv.py:154: FutureWarning: the 'mangle_dupe_cols' keyword is deprecated and will be removed in a future version. Please take steps to stop the use of 'mangle_dupe_cols'
#   csv_file_reader = pd.read_csv(file, iterator=True, dtype=dtype, **self.config.read_csv_kwargs)
# /opt/conda/lib/python3.10/site-packages/datasets/packaged_modules/csv/csv.py:154: FutureWarning: the 'mangle_dupe_cols' keyword is deprecated and will be removed in a future version. Please take steps to stop the use of 'mangle_dupe_cols'
#   csv_file_reader = pd.read_csv(file, iterator=True, dtype=dtype, **self.config.read_csv_kwargs)
# /opt/conda/lib/python3.10/site-packages/datasets/packaged_modules/csv/csv.py:154: FutureWarning: the 'mangle_dupe_cols' keyword is deprecated and will be removed in a future version. Please take steps to stop the use of 'mangle_dupe_cols'
#   csv_file_reader = pd.read_csv(file, iterator=True, dtype=dtype, **self.config.read_csv_kwargs)
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/15274 [00:00<?, ?ex/s]
#   0%|          | 0/3819 [00:00<?, ?ex/s]
#   0%|          | 0/3167 [00:00<?, ?ex/s]
#   0%|          | 0/15274 [00:00<?, ?ex/s]
#   0%|          | 0/3819 [00:00<?, ?ex/s]
#   0%|          | 0/3167 [00:00<?, ?ex/s]
#   0%|          | 0/15274 [00:00<?, ?ex/s]
#   0%|          | 0/3819 [00:00<?, ?ex/s]
#   0%|          | 0/3167 [00:00<?, ?ex/s]
# check data
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
data["train"] = data["train"].map(prepare_dataset, remove_columns=data["train"].column_names)
data["valid"] = data["valid"].map(prepare_dataset, remove_columns=data["valid"].column_names)
data["test"] = data["test"].map(prepare_dataset, remove_columns=data["test"].column_names)
# Out:
#   0%|          | 0/15274 [00:00<?, ?ex/s]
#   0%|          | 0/3819 [00:00<?, ?ex/s]
#   0%|          | 0/3167 [00:00<?, ?ex/s]

# %%
model.config.forced_decoder_ids = None
model.config.suppress_tokens = []

# %%
#pip install accelerate==0.20.1

# %%
from transformers import Seq2SeqTrainingArguments

training_args = Seq2SeqTrainingArguments(
    output_dir="./whisper-small-sw",  # change to a repo name of your choice
    per_device_train_batch_size=4,
    gradient_accumulation_steps=1,  # increase by 2x for every 2x decrease in batch size
    learning_rate=1e-4,
    warmup_steps=500,
    max_steps=10000,
    gradient_checkpointing=True,
    fp16=True,
    evaluation_strategy="steps",
    per_device_eval_batch_size=4,
    predict_with_generate=True,
    generation_max_length=225,
    save_steps=1000,
    eval_steps=1000,
    logging_steps=25,
    report_to=["tensorboard"],
    load_best_model_at_end=True,
    metric_for_best_model="wer",
    greater_is_better=False,
    push_to_hub=False,
)

# %%
data_collator = DataCollatorSpeechSeq2SeqWithPadding(processor=processor)

# %%
from transformers import Seq2SeqTrainer

trainer = Seq2SeqTrainer(
    model=model,
    data_collator=data_collator,
    args=training_args,
    compute_metrics=compute_metrics,
    train_dataset=data["train"],
    eval_dataset=data["valid"],
    tokenizer=processor.feature_extractor,
  )
trainer.train()
# Out:
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
#     <div>
#
#       <progress value='10000' max='10000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [10000/10000 6:44:57, Epoch 2/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Wer</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1000</td>
#       <td>1.814000</td>
#       <td>1.583333</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>1.384900</td>
#       <td>1.410450</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>1.318800</td>
#       <td>1.292987</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>1.054900</td>
#       <td>1.217697</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.932700</td>
#       <td>1.162660</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.809100</td>
#       <td>1.102333</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>0.875100</td>
#       <td>1.040004</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>0.471400</td>
#       <td>1.034217</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>9000</td>
#       <td>0.372400</td>
#       <td>1.017565</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>0.593200</td>
#       <td>1.003575</td>
#       <td>1.000000</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=10000, training_loss=1.0096018758773804, metrics={'train_runtime': 24304.5506, 'train_samples_per_second': 1.646, 'train_steps_per_second': 0.411, 'total_flos': 2.59414040641536e+18, 'train_loss': 1.0096018758773804, 'epoch': 2.62})

# %%
model.save_pretrained(training_args.output_dir)
processor.save_pretrained(training_args.output_dir)

# %%
train
# Out:
#              audio_ID                                               path  \
# 8404   audio_acd9fe97  /kaggle/input/swahili-audio-dataset/all_wav/co...
# 15107  audio_819a598a  /kaggle/input/swahili-audio-dataset/all_wav/co...
# 12774  audio_8fedd6f7  /kaggle/input/swahili-audio-dataset/all_wav/co...
# 425    audio_00d1a130  /kaggle/input/swahili-audio-dataset/all_wav/co...
# 6285   audio_12627e0f  /kaggle/input/swahili-audio-dataset/all_wav/co...
# ...               ...                                                ...
# 11284  audio_4ab93a25  /kaggle/input/swahili-audio-dataset/all_wav/co...
# 11964  audio_868b13da  /kaggle/input/swahili-audio-dataset/all_wav/co...
# 5390   audio_c610a669  /kaggle/input/swahili-audio-dataset/all_wav/co...
# 860    audio_f351ce61  /kaggle/input/swahili-audio-dataset/all_wav/co...
# 15795  audio_4e8073d0  /kaggle/input/swahili-audio-dataset/all_wav/co...
#
#                                                 sentence
# 8404     yatakuja kubadilishwa yakibadilishwa kwa ujumla
# 15107  Itapunguza taka kama vile plastiki na kupunguz...
# 12774     Alikuwa Afisa Mipango Rasilimali Watu Zanzibar
# 425                                Uzuri wake upo jikoni
# 6285   Mto Lukuledi wenye kilometa za mraba elfu kumi...
# ...                                                  ...
# 11284      laba shabani sasa unafikiria tatizo nini hasa
# 11964                 Wakifanya ubaya, uwajibu kwa wema.
# 5390   Wanu Hafidh Ameir ni mwakilishi maalum katika ...
# 860    benki kuu inasimamia soko la hisa la dar es sa...
# 15795  Alikuwa Makamu wa Rais toka mwaka elfu mbili k...
#
# [15274 rows x 3 columns]

# %%
valid
# Out:
#              audio_ID                                               path  \
# 13792  audio_e0a09962  /kaggle/input/swahili-audio-dataset/all_wav/co...
# 3855   audio_2257a639  /kaggle/input/swahili-audio-dataset/all_wav/co...
# 344    audio_0cbda50b  /kaggle/input/swahili-audio-dataset/all_wav/co...
# 12092  audio_a07549f6  /kaggle/input/swahili-audio-dataset/all_wav/co...
# 7882   audio_137dc8b9  /kaggle/input/swahili-audio-dataset/all_wav/co...
# ...               ...                                                ...
# 2777   audio_e162611e  /kaggle/input/swahili-audio-dataset/all_wav/co...
# 257    audio_cf8fd548  /kaggle/input/swahili-audio-dataset/all_wav/co...
# 5923   audio_7e2a7844  /kaggle/input/swahili-audio-dataset/all_wav/co...
# 147    audio_2ec1fba2  /kaggle/input/swahili-audio-dataset/all_wav/co...
# 13285  audio_50439451  /kaggle/input/swahili-audio-dataset/all_wav/co...
#
#                                                 sentence
# 13792  rock hudson alioa mke wake na kutalakiana hapo...
# 3855   Mazingira haya ni pamoja na mipangilio ya kuzu...
# 344      piga hatua sana ya kimaendeleo afrika mashariki
# 12092  Alikimbia lakini walimkamata na kumlazimisha k...
# 7882                               Daktari muoga anakuja
# ...                                                  ...
# 2777   mapokezi ya watalii kwenye hifadhi yanaridhish...
# 257    ni kuchangia na tuangalie kile ambacho wanaoch...
# 5923       amenukuliwa na gazeti la Taifa akisema kwamba
# 147      katika hotuba yake uchumi ndio itakuwa mada kuu
# 13285          kupata hewa safi zaidi Katika nchi nyingi
#
# [3819 rows x 3 columns]

# %%
test
# Out:
#             audio_ID                                               path  \
# 0     audio_3c2f423a  /kaggle/input/swahili-audio-dataset/all_wav/co...
# 1     audio_ca8009ec  /kaggle/input/swahili-audio-dataset/all_wav/co...
# 2     audio_fffcdb86  /kaggle/input/swahili-audio-dataset/all_wav/co...
# 3     audio_0e3e8e6f  /kaggle/input/swahili-audio-dataset/all_wav/co...
# 4     audio_859b792d  /kaggle/input/swahili-audio-dataset/all_wav/co...
# ...              ...                                                ...
# 3162  audio_bdc72517  /kaggle/input/swahili-audio-dataset/all_wav/co...
# 3163  audio_50ee5991  /kaggle/input/swahili-audio-dataset/all_wav/co...
# 3164  audio_b9867662  /kaggle/input/swahili-audio-dataset/all_wav/co...
# 3165  audio_a0739877  /kaggle/input/swahili-audio-dataset/all_wav/co...
# 3166  audio_ae65cf8a  /kaggle/input/swahili-audio-dataset/all_wav/co...
#
#      sentence
# 0
# 1
# 2
# 3
# 4
# ...       ...
# 3162
# 3163
# 3164
# 3165
# 3166
#
# [3167 rows x 3 columns]

# %%
from transformers import (
    AutomaticSpeechRecognitionPipeline,
    WhisperForConditionalGeneration,
    WhisperTokenizer,
    WhisperProcessor,
)

# %%
feature_extractor = processor.feature_extractor
forced_decoder_ids = processor.get_decoder_prompt_ids(language="swahili", task="transcribe")
pipe = AutomaticSpeechRecognitionPipeline(model=model, tokenizer=tokenizer, feature_extractor=feature_extractor, device =0)

# %%
def transcribe(audio):
    with torch.cuda.amp.autocast():
        text = pipe(audio, generate_kwargs={"forced_decoder_ids": forced_decoder_ids}, max_new_tokens=255)["text"]
    return text

transcribe("/kaggle/input/swahili-audio-dataset/all_wav/content/all_wav_files/audio_643a10c1.wav")
# Out:
# 'Alingawa katika mudani za kisiasa na wengozi ndani ya serikali ya mapinduzi ya Zanzanzanzibar'

# %%
predictions = pipe(test.path.to_list(), generate_kwargs={"forced_decoder_ids": forced_decoder_ids})

# %%
preds = [i["text"] for i in predictions]

# %%
test
# Out:
#             audio_ID                                               path  \
# 0     audio_3c2f423a  /kaggle/input/swahili-audio-dataset/all_wav/co...
# 1     audio_ca8009ec  /kaggle/input/swahili-audio-dataset/all_wav/co...
# 2     audio_fffcdb86  /kaggle/input/swahili-audio-dataset/all_wav/co...
# 3     audio_0e3e8e6f  /kaggle/input/swahili-audio-dataset/all_wav/co...
# 4     audio_859b792d  /kaggle/input/swahili-audio-dataset/all_wav/co...
# ...              ...                                                ...
# 3162  audio_bdc72517  /kaggle/input/swahili-audio-dataset/all_wav/co...
# 3163  audio_50ee5991  /kaggle/input/swahili-audio-dataset/all_wav/co...
# 3164  audio_b9867662  /kaggle/input/swahili-audio-dataset/all_wav/co...
# 3165  audio_a0739877  /kaggle/input/swahili-audio-dataset/all_wav/co...
# 3166  audio_ae65cf8a  /kaggle/input/swahili-audio-dataset/all_wav/co...
#
#      sentence
# 0
# 1
# 2
# 3
# 4
# ...       ...
# 3162
# 3163
# 3164
# 3165
# 3166
#
# [3167 rows x 3 columns]

# %%
submission = pd.DataFrame(columns = ['audio_ID','pred_str'])

submission["pred_str"] = preds
submission["audio_ID"] = test.audio_ID
#submission["length"] = [len(i) for i in submission["pred_str"]]
submission.pred_str = submission["pred_str"].replace("", " ")
submission.head()
# Out:
#          audio_ID                                           pred_str
# 0  audio_3c2f423a                                        Chu za vema
# 1  audio_ca8009ec  Ni na umbali wa utawakogopita na kugambulia ya...
# 2  audio_fffcdb86                                  ya shari vijakana
# 3  audio_0e3e8e6f                       Hajibiki kipindiisha la usho
# 4  audio_859b792d  Goma hapa wa kimwambia mtutwenda rubar hata ju...

# %%
submission.to_csv("10 epochs of Whisper Swahili Base v2.csv", index=False)
